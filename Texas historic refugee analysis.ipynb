# %%
import pandas as pd

# %%
df = pd.read_csv('coco_refugee_data_1975_2018.csv')

# %%
df.head()
# Out:
#    city_id  city_nat_id  city_nat_year_id  year citizenship_stable  refugees  \
# 0     2645         9267             34286  1976            vietnam         1
# 1     2645         9267             34287  1978            vietnam         1
# 2     2646         9268             34288  2007              burma         3
# 3     2646         9268             34289  2008              burma         5
# 4     2646         9269             34290  1975           cambodia         4
#
#       city  city_code county_fips  state_fips   fips county10name  countyfp10  \
# 0      NaN    10110.0         141          48  48141      El Paso         141
# 1      NaN    27800.0         141          48  48141      El Paso         141
# 2  El Paso    24000.0         141          48  48141      El Paso         141
# 3  El Paso    24000.0         141          48  48141      El Paso         141
# 4  El Paso    24000.0         141          48  48141      El Paso         141
#
# ...

# %%
df.sort_values('year')
# Out:
#       city_id  city_nat_id  city_nat_year_id  year citizenship_stable  \
# 7328     4735        14744             51293  1975            vietnam
# 1526     3358        11012             39386  1975            vietnam
# 1546     3365        11031             39425  1975            vietnam
# 1548     3366        11032             39427  1975            vietnam
# 1549     3367        11033             39428  1975            vietnam
# ...       ...          ...               ...   ...                ...
# 1318     3223        10771             38887  2018    dem. rep. congo
# 2794     3557        11624             41516  2018    dem. rep. congo
# 1435     3292        10900             39209  2018               iraq
# 5133     3804        12683             45369  2018              burma
# 742      3077        10475             38091  2018        ivory coast
#
#       refugees            city  city_code county_fips  state_fips   fips  \
# ...

# %%
df.citizenship_stable
# Out:
# 0        vietnam
# 1        vietnam
# 2          burma
# 3          burma
# 4       cambodia
#           ...
# 7324     vietnam
# 7325     vietnam
# 7326     vietnam
# 7327     vietnam
# 7328     vietnam
# Name: citizenship_stable, Length: 7329, dtype: object

# %%
cols_of_interest =['citizenship_stable','year']
df [cols_of_interest]
# Out:
#      citizenship_stable  year
# 0               vietnam  1976
# 1               vietnam  1978
# 2                 burma  2007
# 3                 burma  2008
# 4              cambodia  1975
# ...                 ...   ...
# 7324            vietnam  1975
# 7325            vietnam  1977
# 7326            vietnam  1979
# 7327            vietnam  1975
# 7328            vietnam  1975
#
# [7329 rows x 2 columns]

# %%
df.sort_values('year')
# Out:
#       city_id  city_nat_id  city_nat_year_id  year citizenship_stable  \
# 7328     4735        14744             51293  1975            vietnam
# 1526     3358        11012             39386  1975            vietnam
# 1546     3365        11031             39425  1975            vietnam
# 1548     3366        11032             39427  1975            vietnam
# 1549     3367        11033             39428  1975            vietnam
# ...       ...          ...               ...   ...                ...
# 1318     3223        10771             38887  2018    dem. rep. congo
# 2794     3557        11624             41516  2018    dem. rep. congo
# 1435     3292        10900             39209  2018               iraq
# 5133     3804        12683             45369  2018              burma
# 742      3077        10475             38091  2018        ivory coast
#
#       refugees            city  city_code county_fips  state_fips   fips  \
# ...

# %%
vietnam = df[df.citizenship_stable == 'vietnam']

# %%
vietnam_1975 = vietnam[vietnam.year == 1975]

# %%
vietnam_1975
# Out:
#       city_id  city_nat_id  city_nat_year_id  year citizenship_stable  \
# 37       2646         9278             34323  1975            vietnam
# 67       2780         9882             36529  1975            vietnam
# 70       2885        10080             36969  1975            vietnam
# 90       2905        10105             37006  1975            vietnam
# 103      2910        10117             37022  1975            vietnam
# ...       ...          ...               ...   ...                ...
# 7309     4676        14632             51013  1975            vietnam
# 7323     4677        14634             51027  1975            vietnam
# 7324     4681        14639             51032  1975            vietnam
# 7327     4702        14668             51087  1975            vietnam
# 7328     4735        14744             51293  1975            vietnam
#
#       refugees         city  city_code county_fips  state_fips   fips  \
# ...

# %%
df.groupby('citizenship_stable').sum()
# Out:
#                     city_id  city_nat_id  city_nat_year_id     year  refugees  \
# citizenship_stable
# afghanistan          679656      2231655           7946092   371670      2405
# albania               49977       162687            576241    25889        51
# algeria               12478        40418            142526     5999        39
# angola                39551       128347            453723    20014        40
# bahrain                4198        13566             47773     2000         5
# ...                     ...          ...               ...      ...       ...
# vietnam             7304438     23966005          85321757  3872949     75982
# yemen                  7581        24747             88097     4015         4
# yugoslavia           684087      2251667           8030547   371582      9459
# zambia                 6766        22244             79725     4033         2
# zimbabwe               7452        24564             87165     4031         9
#
# ...

# %%
df[['citizenship_stable','refugees']].groupby('citizenship_stable').sum()
# Out:
#                     refugees
# citizenship_stable
# afghanistan             2405
# albania                   51
# algeria                   39
# angola                    40
# bahrain                    5
# ...                      ...
# vietnam                75982
# yemen                      4
# yugoslavia              9459
# zambia                     2
# zimbabwe                   9
#
# [91 rows x 1 columns]

# %%
df[['citizenship_stable','refugees']].groupby('citizenship_stable').sum().sort_values('refugees',ascending=False)
# Out:
#                     refugees
# citizenship_stable
# vietnam                75982
# burma                  23042
# iraq                   16991
# cambodia               12794
# laos                   11644
# ...                      ...
# canada                     1
# lesotho                    1
# mali                       1
# other                      1
# netherlands                1
#
# [91 rows x 1 columns]

# %%
df[['citizenship_stable','refugees']].groupby('citizenship_stable').sum().sort_values('refugees',ascending=False).head(10)
# Out:
#                     refugees
# citizenship_stable
# vietnam                75982
# burma                  23042
# iraq                   16991
# cambodia               12794
# laos                   11644
# somalia                 9969
# yugoslavia              9459
# bhutan                  8342
# dem. rep. congo         7229
# iran                    6417

# %%
df[['citizenship_stable','refugees','year']].groupby('citizenship_stable').sum().sort_values('refugees',ascending=False)
# Out:
#                     refugees     year
# citizenship_stable
# vietnam                75982  3872949
# burma                  23042   651470
# iraq                   16991  1008145
# cambodia               12794   519324
# laos                   11644   644568
# ...                      ...      ...
# canada                     1     2008
# lesotho                    1     1988
# mali                       1     2012
# other                      1     1979
# netherlands                1     2015
#
# [91 rows x 2 columns]

# %%
df.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})
# Out:
#                         refugees
#                              sum
# citizenship_stable year
# afghanistan        1981       58
#                    1982       16
#                    1983       76
#                    1984       80
#                    1985       84
# ...                          ...
# yugoslavia         2004        4
# zambia             2016        1
#                    2017        1
# zimbabwe           2013        1
#                    2018        8
#
# [951 rows x 1 columns]

# %%
vietnam = df[df['citizenship_stable']== 'vietnam']

# %%
vietnam
# Out:
#       city_id  city_nat_id  city_nat_year_id  year citizenship_stable  \
# 0        2645         9267             34286  1976            vietnam
# 1        2645         9267             34287  1978            vietnam
# 37       2646         9278             34323  1975            vietnam
# 38       2646         9278             34324  1977            vietnam
# 39       2646         9278             34325  1978            vietnam
# ...       ...          ...               ...   ...                ...
# 7324     4681        14639             51032  1975            vietnam
# 7325     4681        14639             51033  1977            vietnam
# 7326     4681        14639             51034  1979            vietnam
# 7327     4702        14668             51087  1975            vietnam
# 7328     4735        14744             51293  1975            vietnam
#
#       refugees         city  city_code county_fips  state_fips   fips  \
# ...

# %%
vietnam.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})
# Out:
#                         refugees
#                              sum
# citizenship_stable year
# vietnam            1975     8264
#                    1976       29
#                    1977      537
#                    1978     1476
#                    1979     5194
#                    1980     7898
#                    1981     5125
#                    1982     4518
#                    1983     2329
#                    1984     2527
#                    1985     2393
#                    1986     1779
#                    1987     1690
#                    1988     1694
#                    1989     3500
#                    1990      691
#                    1991     3988
#                    1992     3920
#                    1993     3880
#                    1994     3795
#                    1995     3390
#                    1996     1424
#                    1997      732
#                    1998     1882
#                    1999      863
# ...

# %%
vietnam_group = vietnam.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})

# %%
vietnam_group
# Out:
#                         refugees
#                              sum
# citizenship_stable year
# vietnam            1975     8264
#                    1976       29
#                    1977      537
#                    1978     1476
#                    1979     5194
#                    1980     7898
#                    1981     5125
#                    1982     4518
#                    1983     2329
#                    1984     2527
#                    1985     2393
#                    1986     1779
#                    1987     1690
#                    1988     1694
#                    1989     3500
#                    1990      691
#                    1991     3988
#                    1992     3920
#                    1993     3880
#                    1994     3795
#                    1995     3390
#                    1996     1424
#                    1997      732
#                    1998     1882
#                    1999      863
# ...

# %%
vietnam_group.to_csv('vietnam_refugees.csv')

# %%
iraq = df[df['citizenship_stable']== 'iraq']

# %%
iraq
# Out:
#       city_id  city_nat_id  city_nat_year_id  year citizenship_stable  \
# 25       2646         9273             34311  2007               iraq
# 26       2646         9273             34312  2008               iraq
# 58       2647         9281             34344  2009               iraq
# 59       2647         9281             34345  2010               iraq
# 60       2647         9281             34346  2012               iraq
# ...       ...          ...               ...   ...                ...
# 7150     4462        14256             50066  2008               iraq
# 7156     4485        14295             50141  2014               iraq
# 7247     4633        14557             50806  2008               iraq
# 7296     4657        14605             50965  2009               iraq
# 7297     4657        14605             50966  2012               iraq
#
#       refugees         city  city_code county_fips  state_fips   fips  \
# ...

# %%
iraq.to_csv('iraq_refugees.csv')

# %%
iraq.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})
# Out:
#                         refugees
#                              sum
# citizenship_stable year
# iraq               1982        7
#                    1983       22
#                    1984        7
#                    1985        7
#                    1986       11
#                    1987        7
#                    1988        1
#                    1989        1
#                    1991      251
#                    1992      292
#                    1993      328
#                    1994      286
#                    1995      150
#                    1996      209
#                    1997      226
#                    1998      104
#                    1999      151
#                    2000      329
#                    2001      155
#                    2002       52
#                    2003       22
#                    2004       29
#                    2005       20
#                    2006       22
#                    2007      110
# ...

# %%
iraq_group = iraq.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})

# %%
iraq_group
# Out:
#                         refugees
#                              sum
# citizenship_stable year
# iraq               1982        7
#                    1983       22
#                    1984        7
#                    1985        7
#                    1986       11
#                    1987        7
#                    1988        1
#                    1989        1
#                    1991      251
#                    1992      292
#                    1993      328
#                    1994      286
#                    1995      150
#                    1996      209
#                    1997      226
#                    1998      104
#                    1999      151
#                    2000      329
#                    2001      155
#                    2002       52
#                    2003       22
#                    2004       29
#                    2005       20
#                    2006       22
#                    2007      110
# ...

# %%
iraq_group.to_csv('iraq_refugees.csv')

# %%
afghanistan = df[df['citizenship_stable']== 'afghanistan']

# %%
afghanistan
# Out:
#       city_id  city_nat_id  city_nat_year_id  year citizenship_stable  \
# 73       2891        10089             36980  1983        afghanistan
# 270      2942        10178             37202  2010        afghanistan
# 271      2942        10178             37203  2014        afghanistan
# 354      2943        10195             37286  2000        afghanistan
# 355      2943        10195             37287  2001        afghanistan
# ...       ...          ...               ...   ...                ...
# 6209     4198        13562             47759  2006        afghanistan
# 6210     4198        13562             47760  2007        afghanistan
# 6211     4198        13562             47761  2008        afghanistan
# 7181     4608        14508             50671  1983        afghanistan
# 7262     4638        14573             50889  1983        afghanistan
#
#       refugees         city  city_code county_fips  state_fips   fips  \
# ...

# %%
afghanistan.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})
# Out:
#                         refugees
#                              sum
# citizenship_stable year
# afghanistan        1981       58
#                    1982       16
#                    1983       76
#                    1984       80
#                    1985       84
#                    1986      128
#                    1987      164
#                    1988       28
#                    1989       44
#                    1990        7
#                    1991       20
#                    1992       25
#                    1993        3
#                    1999        8
#                    2000      137
#                    2001      250
#                    2002      183
#                    2003       99
#                    2004       67
#                    2005      107
#                    2006       83
#                    2007       48
#                    2008       19
#                    2009       21
#                    2010       34
# ...

# %%
afghanistan_group = afghanistan.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})

# %%
afghanistan_group
# Out:
#                         refugees
#                              sum
# citizenship_stable year
# afghanistan        1981       58
#                    1982       16
#                    1983       76
#                    1984       80
#                    1985       84
#                    1986      128
#                    1987      164
#                    1988       28
#                    1989       44
#                    1990        7
#                    1991       20
#                    1992       25
#                    1993        3
#                    1999        8
#                    2000      137
#                    2001      250
#                    2002      183
#                    2003       99
#                    2004       67
#                    2005      107
#                    2006       83
#                    2007       48
#                    2008       19
#                    2009       21
#                    2010       34
# ...

# %%
afghanistan_group.to_csv('afghanistan_refugees.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('coco_refugee_data_1975_2018.csv')

# %%
df[['citizenship_stable','refugees']].groupby('citizenship_stable').sum()
# Out:
#                     refugees
# citizenship_stable
# afghanistan             2405
# albania                   51
# algeria                   39
# angola                    40
# bahrain                    5
# ...                      ...
# vietnam                75982
# yemen                      4
# yugoslavia              9459
# zambia                     2
# zimbabwe                   9
#
# [91 rows x 1 columns]

# %%
df.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})
# Out:
#                         refugees
#                              sum
# citizenship_stable year
# afghanistan        1981       58
#                    1982       16
#                    1983       76
#                    1984       80
#                    1985       84
# ...                          ...
# yugoslavia         2004        4
# zambia             2016        1
#                    2017        1
# zimbabwe           2013        1
#                    2018        8
#
# [951 rows x 1 columns]

# %%
total_refugees_by_year_tx=df.groupby(['citizenship_stable', 'year']).aggregate(
    {'refugees': ['sum']})

# %%
total_refugees_by_year_tx.to_csv('total_refugees_by_year_tx.csv')

# %%
import pandas as pd

# %%
data = pd.io.stata.read_stata('orr_prm_1975_2018_v1.dta')

# %%
data.to_csv('orr_prm_1975_2018_v1.csv')

# %%
df = pd.read_csv('orr_prm_1975_2018_v1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  city_id  city_nat_id  city_nat_year_id  year  \
# 0           0      1.0          1.0               1.0  1983
# 1           1      1.0          1.0               2.0  1984
# 2           2      1.0          1.0               3.0  1987
# 3           3      1.0          1.0               4.0  1988
# 4           4      1.0          2.0               5.0  1983
#
#   citizenship_stable  refugees      city  city_code county_fips state_fips  \
# 0        afghanistan      17.0  Honolulu    17000.0         003         15
# 1        afghanistan      11.0  Honolulu    17000.0         003         15
# 2        afghanistan       2.0  Honolulu    17000.0         003         15
# 3        afghanistan       1.0  Honolulu    17000.0         003         15
# 4           bulgaria       1.0  Honolulu    17000.0         003         15
#
#     fips county10name  countyfp10  statefp10 geo_level   longitude   latitude  \
# ...

# %%
df.groupby('state_fips').aggregate(
    {'refugees': ['sum']})
# Out:
#             refugees
#                  sum
# state_fips
# .                7.0
# 01            9683.0
# 02            2304.0
# 04           72399.0
# 05            6860.0
# 06          654055.0
# 08           46945.0
# 09           30646.0
# 10            1105.0
# 11           20120.0
# 12          126448.0
# 13           87849.0
# 15           11181.0
# 16           21225.0
# 17          121791.0
# 18           29799.0
# 19           35336.0
# 20           22650.0
# 21           37617.0
# 22           24814.0
# 23            9601.0
# 24           47638.0
# 25           83942.0
# 26           86268.0
# 27          105575.0
# 28            3068.0
# 29           55822.0
# 30            2260.0
# 31           23714.0
# 32           14912.0
# 33           12038.0
# 34           43624.0
# 35           11353.0
# 36          297933.0
# 37           53199.0
# 38           12745.0
# 39           69026.0
# 40           20024.0
# 41           58957.0
# 42          108461.0
# ...

# %%
total_refugees_by_state_1975_to_2018=df.groupby('state_fips').aggregate(
    {'refugees': ['sum']})

# %%
total_refugees_by_state_1975_to_2018.to_csv('total_refugees_by_state_1975_to_2018.csv')
